# %%
import bia_bob
bia_bob.__version__
# Out:
# '0.33.0'

# %%
# %%bob
# load icd10gm2025syst_kodes.csv and use ";" as delimiter
# Out:
#             <div style="font-size:7pt">
#             This notebook may contain text, code and images generated by artificial intelligence.
#             Used model: gpt-4o-2024-08-06, vision model: gpt-4o-2024-08-06, endpoint: None, bia-bob version: 0.33.0.. Do not enter sensitive or private information and verify generated contents according to good scientific practice. Read more: <a href="https://github.com/haesleinhuepf/bia-bob#disclaimer">https://github.com/haesleinhuepf/bia-bob#disclaimer</a>
#             </div>
# I will load the CSV file `icd10gm2025syst_kodes.csv` with ";" as the delimiter using the pandas library.

# %%
# Out:
#            6                                                  8
# 2790     F00                     Demenz bei Alzheimer-Krankheit
# 2791   F00.0  Demenz bei Alzheimer-Krankheit, mit frühem Beg...
# 2792   F00.1  Demenz bei Alzheimer-Krankheit, mit spätem Beg...
# 2793   F00.2  Demenz bei Alzheimer-Krankheit, atypische oder...
# 2794   F00.9  Demenz bei Alzheimer-Krankheit, nicht näher be...
# ...      ...                                                ...
# 3304   F98.8  Sonstige näher bezeichnete Verhaltens- und emo...
# 3305  F98.80  Aufmerksamkeitsstörung ohne Hyperaktivität mit...
# 3306  F98.88  Sonstige näher bezeichnete Verhaltens- und emo...
# 3307   F98.9  Nicht näher bezeichnete Verhaltens- oder emoti...
# 3308     F99              Psychische Störung ohne nähere Angabe
#
# [519 rows x 2 columns]
